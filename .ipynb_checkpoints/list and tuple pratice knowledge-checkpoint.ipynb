# %%
a = [10,20,30,"sridevi"]
b = a.copy()
a.append("40")
a.append("sai")
a.append(["dolly"])
a.append(50)
a.extend("32")
a.extend("5")
a.extend("madhu")
a.extend(["kalyan"])
print(a)
print(b)
print(a.pop())
# Out:
# [10, 20, 30, 'sridevi', '40', 'sai', ['dolly'], 50, '3', '2', '5', 'm', 'a', 'd', 'h', 'u', 'kalyan']
# [10, 20, 30, 'sridevi']
# kalyan

# %%
print(int(True)+len(tuple("ab")))
# Out:
#   Cell In[26], line 1
#     print(int(True)+len(tuple("ab"))
#                                     ^
# _IncompleteInputError: incomplete input
