# %%
s = "2344"
print(s.isdigit())
a = "123dad"
print(a.isalnum())
# Out:
# True
# True

# %%
s = "sai"
print(s.isalpha())
# Out:
# True

# %%
print("ABCABCABD".count("ABC"))
print("ABCABCABC".count("A"))
print("ABCABCABC".count("C"))
# Out:
# 2
# 3
# 3

# %%
lst = ['The','ocean','is','blue']
print("".join(lst))
print(" ".join(lst))
print("_".join(lst))
print("A"
# Out:
# Theoceanisblue
# The ocean is blue
# The_ocean_is_blue

# %%
2**3
# Out:
# 8

# %%
8**2
# Out:
# 64

# %%
2**9
# Out:
# 512

# %%
a = 4
b = 3
print(a.copy())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 3
#       1 a = 4
#       2 b = 3
# ----> 3 print(a.copy())
#
# AttributeError: 'int' object has no attribute 'copy'
