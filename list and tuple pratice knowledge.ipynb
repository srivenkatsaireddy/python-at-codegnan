# %%
a = [10,20,30,"sridevi"]
b = a.copy()
a.append("40")
a.append("sai")
a.append(["dolly"])
a.append([25])
a.append(50)
a.extend("32")
a.extend("5")
a.extend("madhu")
a.extend(["kalyan"])
a.extend(["35"])
print(a)
print(b)
#print(a.pop())
# Out:
# [10, 20, 30, 'sridevi', '40', 'sai', ['dolly'], [25], 50, '3', '2', '5', 'm', 'a', 'd', 'h', 'u', 'kalyan', '35']
# [10, 20, 30, 'sridevi']

# %%
print(int(True)+len(tuple("ab")))
# Out:
# 3

# %%
print(True)
# Out:
# True

# %%
print(str(True))
# Out:
# True

# %%
print(int(True))
# Out:
# 1

# %%
tuple =(23,40, 2, 1,"venkat")
print(tuple)
print(type(tuple))
# Out:
# (23, 40, 2, 1, 'venkat')
# <class 'tuple'>

# %%
s = "codegnan"
print(s[:5])
print(s[:-4])
# Out:
# codeg
# code

# %%
s = "codegnan"
print(s[-1:2:1])

# %%
s = "codegnan"
print(s[-1:2:1])
