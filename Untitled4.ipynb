# %%
text = input("enter a sentence:")
print(text)
clean_text = text.strip()
print(clean_text)
lower_text = clean_text.lower()
print(lower_text)
words = lower_text.split()
print(words)
print(type(words))
print(len(words))
unique_words = len(set(words))
print(unique_words)
char_count = clean_text.replace(" ","")
print(char_count)
char_count_len = len(clean_text.replace(" ",""))
print(char_count_len)
# Out:
# enter a sentence:  Hi I am Sai sai
#  Hi I am Sai sai
# Hi I am Sai sai
# hi i am sai sai
# ['hi', 'i', 'am', 'sai', 'sai']
# <class 'list'>
# 5
# 4
# HiIamSaisai
# 11

# %%
num = chr(65)
print(num)
char = ord('a')
print(char)
# Out:
# A
# 97

# %%
text = input()
reverse = text[::-1]
print(reverse)
# Out:
#  sai
# ias

# %%
text = input()
rev = ""
for i in text:
    rev = rev + i
    print(rev)
# Out:
#  sai
# s
# sa
# sai

# %%
text = input()
rev = ""
for i in text:
    rev = i + rev
    print(rev)
# Out:
#  sai
# s
# as
# ias

# %%
text = input()
reverse = text[::-1]
print(reverse)
if text == reverse:
    print("palindrome")
# Out:
#  sas
# sas
# palindrome

# %%
text = input()
vowel_count = 0
consonant_count = 0
for i in text:
   if i in 'aeiouAEIOU':
       vowel_count = vowel_count + 1
   else:
      consonant_count = consonant_count + 1
print(vowel_count)
print(consonant_count)
# Out:
#  venkat
# 2
# 4

# %%
N = int(input())
for i in range(1,N+1):
    print(i)
# Out:
#  5
# 1
# 2
# 3
# 4
# 5

# %%
N = int(input())
for i in range(2,N+1,2):
    print(i)
# Out:
#  5
# 2
# 4

# %%
while True:
    X = int(input())
    if X == 1999:
        print("Correct")
        break
    else:
        print("Wrong")
# Out:
#  2200
# Wrong
#  1020
# Wrong
#  23
# Wrong
#  344
# Wrong
#  44545
# Wrong
#  5
# Wrong
#  5
# Wrong
#  1999
# Correct

# %%
N = int(input())
num = map(int,input().split())
s = max(num)
print(s)
# Out:
#  5
#  1 8 5 7 5
# 8

# %%
N = int(input())
for i in range(1,13):
    mul = N * i
    print(f"{N} * {i} = {mul}")
# Out:
#  2
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 2 * 10 = 20
# 2 * 11 = 22
# 2 * 12 = 24

# %%
N = int(input())
num1 = int(input())
fact  = 1
num2 = int(input())
fact2 = 1
for i in range(1,num1+1):
    fact = i * fact
for i in range(1,num2+1):
    fact2 = i * fact2
print(fact)
print(fact2)
# Out:
#  2
#  5
#  3
# 120
# 6

# %%
T = int(input())

for _ in range(T):
    N = int(input())

    factorial = 1

    for i in range(1, N + 1):
        factorial *= i

    print(factorial)
# Out:
#  2
#  5
# 120
#  3
# 6

# %%
X = int(input())
for i in range(2,X+1):
    if X % i == 0:
        s = len(x % i == 0)
    if s <= 2:
        print("YES")
        break
    else:
        print("NO")
# Out:
#  7
# NO
# NO
# NO
# NO
# NO
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 4
#       1 X = int(input())
#       2 for i in range(2,X+1):
#       3     if X % i == 0:
# ----> 4         s = len(x % i == 0)
#       5     if s <= 2:
#       6         print("YES")
#       7         break
#
# NameError: name 'x' is not defined

# %%
N = input()
s = N[::-1]
if s == N:
    print(N)
    print("YES")
elif s != N:
    print(s)
    print("NO")
# Out:
#  160
# 061
# NO

# %%
N = input()

# Reverse the number and remove leading zeros
rev = str(int(N[::-1]))

print(rev)

if N == rev:
    print("YES")
else:
    print("NO")
# Out:
#  610
# 16
# NO

# %%
N = int(input())
M = int(input())
for i in range(1,N+1):
    if N % i == 0:

        for j in range(1,N+1):
            if M % i == 0:
               print(i == j)
# Out:
#  12
#  8
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
